# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data_in_cluster.csv')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   author_name       5279 non-null   object
#  1   affiliation       5279 non-null   object
#  2   city              5279 non-null   object
#  3   country           5279 non-null   object
#  4   publication_date  5279 non-null   object
#  5   title             5279 non-null   object
#  6   latitude          5279 non-null   float64
#  7   longitude         5279 non-null   float64
#  8   cluster           5279 non-null   int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 371.3+ KB
#           latitude    longitude      cluster
# count  5279.000000  5279.000000  5279.000000
# mean     33.830155    39.096994     2.088085
# std      17.730533    81.482388     3.385491
# min     -42.882509  -149.894852    -1.000000
# 25%      30.595105    -2.245115     0.000000
# ...

# %%
df[df['cluster'] == 0]
# Out:
#        author_name                                        affiliation  \
# 0      Niwiński A.                               University of Warsaw
# 10    Elmounadi A.                     Mohammed V University in Rabat
# 13    Lyashenko V.   Kharkiv National University of Radio Electronics
# 18       Gorsse S.                                       Bordeaux INP
# 19       Gorsse S.                             Université de Bordeaux
# ...            ...                                                ...
# 5270    Levitin G.                   Israel Electric Corporation Ltd.
# 5273    Coppens P.  Leuvens Centrum voor Onderwijs van Ingenieurs ...
# 5274    Coppens P.                                          KU Leuven
# 5276      Zhang Q.            Université Toulouse III - Paul Sabatier
# 5278      Zhang Q.  CNRS Centre National de la Recherche Scientifique
#
#           city  country publication_date  \
# 0       Warsaw   Poland       2017-12-31
# ...
